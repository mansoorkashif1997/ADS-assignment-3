# %%
import pandas as pd
import numpy as np
from sklearn.cluster import KMeans
from sklearn.preprocessing import StandardScaler
from sklearn.metrics import silhouette_score
from scipy.optimize import curve_fit
import matplotlib.pyplot as plt

# %%
# User-defined function to read data
def read_data(file_path):
    df = pd.read_csv(file_path)
    return df

file_path="f29023c7-220d-46e2-b658-0c7cc858eed4_Data.csv"
df = read_data(file_path)
df
# Out:
#                                            Series Name           Country Name  \
# 0    Total greenhouse gas emissions (kt of CO2 equi...            Afghanistan
# 1    Total greenhouse gas emissions (kt of CO2 equi...                Albania
# 2    Total greenhouse gas emissions (kt of CO2 equi...                Algeria
# 3    Total greenhouse gas emissions (kt of CO2 equi...         American Samoa
# 4    Total greenhouse gas emissions (kt of CO2 equi...                Andorra
# ..                                                 ...                    ...
# 646                       Forest area (% of land area)  Virgin Islands (U.S.)
# 647                       Forest area (% of land area)     West Bank and Gaza
# 648                       Forest area (% of land area)            Yemen, Rep.
# 649                       Forest area (% of land area)                 Zambia
# 650                       Forest area (% of land area)               Zimbabwe
#
#             1990         2020
# ...

# %%
# User-defined function for data preprocessing
def preprocess_data(df):
    # Pivot the dataframe to have years as columns
    df_pivot = df.pivot_table(index=['Country Name', 'Series Name']).reset_index()

    # Clean the data (handle missing values, etc.)
    df_cleaned = df_pivot.dropna()

    return df_cleaned

df_cleaned = preprocess_data(df)
df_cleaned
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# File c:\Users\Zain\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\groupby.py:1874, in GroupBy._agg_py_fallback(self, how, values, ndim, alt)
#    1873 try:
# -> 1874     res_values = self.grouper.agg_series(ser, alt, preserve_dtype=True)
#    1875 except Exception as err:
#
# File c:\Users\Zain\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:850, in BaseGrouper.agg_series(self, obj, func, preserve_dtype)
#     848     preserve_dtype = True
# --> 850 result = self._aggregate_series_pure_python(obj, func)
#     852 npvalues = lib.maybe_convert_objects(result, try_float=False)
#
# File c:\Users\Zain\AppData\Local\Programs\Python\Python312\Lib\site-packages\pandas\core\groupby\ops.py:871, in BaseGrouper._aggregate_series_pure_python(self, obj, func)
# ...
